# %%
import os
import sys
# ABY FUNGOVALI relativne importy
root_path = os.path.abspath(os.path.join('..', '..')) 
if root_path not in sys.path:
    sys.path.insert(0, root_path)
__package__ = "source.analysis" 

from ..data.sentiment import return_sentiment_agg_pivot

# %%
return_sentiment_agg_pivot(with_label=False)
# Out:
#           date  finbert_IS_max  finbert_QA_max  roberta_IS_max  \
# 0   1998-06-09        0.631409        0.714346        0.431860
# 1   1998-07-08        0.862429        0.714346        0.955640
# 2   1998-09-11        0.343771        0.714346        0.912961
# 3   1998-10-13        0.606811        0.599178        0.671969
# 4   1998-11-03        0.820239        0.888793        0.615113
# ..         ...             ...             ...             ...
# 284 2025-06-05        0.934942        0.898165        0.921795
# 285 2025-07-24        0.934826        0.419589        0.929459
# 286 2025-09-11        0.939982        0.725682        0.904839
# 287 2025-10-30        0.908642        0.917640        0.869237
# 288 2025-12-18        0.929824        0.879382        0.964923
#
#      roberta_QA_max  finbert_IS_mean  finbert_QA_mean  roberta_IS_mean  \
# 0          0.678628         0.099862         0.053400        -0.216860
# 1          0.678628         0.221894         0.053400        -0.187347
# 2          0.678628        -0.104601         0.053400        -0.195902
# 3          0.210729         0.026842         0.003883        -0.316836
# 4          0.732333        -0.084367         0.007413        -0.164700
# ..              ...              ...              ...              ...
# 284        0.807872        -0.017217         0.272963        -0.125203
# 285        0.736285        -0.003801         0.032179        -0.081689
# 286        0.581931        -0.095442         0.109310        -0.091597
# 287        0.962695         0.105237         0.145053        -0.000254
# 288        0.933611         0.208491         0.041969         0.045142
#
#      roberta_QA_mean  finbert_IS_min  finbert_QA_min  roberta_IS_min  \
# 0          -0.340165       -0.015004       -0.597365       -0.875000
# 1          -0.340165        0.002228       -0.597365       -0.803244
# 2          -0.340165       -0.869507       -0.597365       -0.957097
# 3          -0.442629       -0.959836       -0.748550       -0.944551
# 4          -0.269302       -0.907782       -0.609886       -0.952930
# ..               ...             ...             ...             ...
# 284        -0.092317       -0.947328       -0.121825       -0.951756
# 285        -0.334592       -0.956847       -0.874056       -0.964396
# 286        -0.355386       -0.961251       -0.412330       -0.950050
# 287        -0.150716       -0.968406       -0.295853       -0.961296
# 288        -0.351303       -0.950697       -0.820515       -0.945490
#
#      roberta_QA_min  finbert_IS_std  finbert_QA_std  roberta_IS_std  \
# 0         -0.907268        0.183625        0.275152        0.350154
# 1         -0.907268        0.281861        0.275152        0.402142
# 2         -0.907268        0.341010        0.275152        0.548713
# 3         -0.871307        0.340447        0.233765        0.384581
# 4         -0.893488        0.425196        0.276492        0.467149
# ..              ...             ...             ...             ...
# 284       -0.926759        0.738439        0.309186        0.613973
# 285       -0.902922        0.793389        0.259110        0.580374
# 286       -0.941338        0.705788        0.236990        0.437758
# 287       -0.952956        0.714895        0.227566        0.625657
# 288       -0.943373        0.701611        0.284551        0.558513
#
#      roberta_QA_std
# 0          0.433160
# 1          0.433160
# 2          0.433160
# 3          0.358225
# 4          0.420890
# ..              ...
# 284        0.484735
# 285        0.506236
# 286        0.372876
# 287        0.563319
# 288        0.511455
#
# [289 rows x 17 columns]
